# %% [markdown]
# # QyPt5 Application

# %% [markdown]
# #### Very Last Code is the final one, everything else is for your understanding if you need to update or any thing else!

# %% [markdown]
# ### With Buttons

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QRadioButton, QLineEdit, QPushButton, QVBoxLayout, QHBoxLayout, QFileDialog
from PyQt5.QtGui import QPixmap
from PyQt5.QtCore import Qt


class MainWindow(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    def initUI(self):
        # Create radio buttons
        self.radio_male = QRadioButton('Male')
        self.radio_female = QRadioButton('Female')
        self.radio_male.setChecked(True)  # Set default as Male

        # Create name text box
        self.text_name = QLineEdit()

        # Create image box
        self.image_label = QLabel()
        self.image_label.setFixedSize(200, 200)
        self.btn_upload_image = QPushButton('Upload Image')
        self.btn_upload_image.clicked.connect(self.openImage)

        # Create video text box
        self.video_label = QLabel()
        self.video_label.setFixedSize(200, 200)
        self.btn_upload_video = QPushButton('Upload Video')
        self.btn_upload_video.clicked.connect(self.openVideo)

        # Create buttons
        self.btn_submit_video = QPushButton('Submit Video')
        self.btn_submit_name_gender = QPushButton('Save Name and Gender')
        self.btn_submit_name_gender.clicked.connect(self.saveNameGender)

        # Create layouts
        layout_gender = QHBoxLayout()
        layout_gender.addWidget(self.radio_male)
        layout_gender.addWidget(self.radio_female)

        layout_name = QHBoxLayout()
        layout_name.addWidget(QLabel('Name: '))
        layout_name.addWidget(self.text_name)

        layout_image = QVBoxLayout()
        layout_image.addWidget(QLabel('Image:'))
        layout_image.addWidget(self.image_label)
        layout_image.addWidget(self.btn_upload_image)

        layout_video = QVBoxLayout()
        layout_video.addWidget(QLabel('Video:'))
        layout_video.addWidget(self.video_label)
        layout_video.addWidget(self.btn_upload_video)

        layout_buttons = QHBoxLayout()
        layout_buttons.addWidget(self.btn_submit_video)
        layout_buttons.addWidget(self.btn_submit_name_gender)

        layout_main = QVBoxLayout()
        layout_main.addLayout(layout_gender)
        layout_main.addLayout(layout_name)
        layout_main.addLayout(layout_image)
        layout_main.addLayout(layout_video)
        layout_main.addLayout(layout_buttons)

        self.setLayout(layout_main)
        self.setWindowTitle('My Application')
        self.show()

    def openImage(self):
        filename, _ = QFileDialog.getOpenFileName(self, "Select Image", "", "Image Files (*.png *.jpg *jpeg *.bmp)")
        if filename:
            pixmap = QPixmap(filename)
            pixmap = pixmap.scaled(200, 200, Qt.KeepAspectRatio)
            self.image_label.setPixmap(pixmap)

    def openVideo(self):
        filename, _ = QFileDialog.getOpenFileName(self, "Select Video", "", "Video Files (*.mp4)")
        if filename:
            self.video_label.setText(filename)

    def saveNameGender(self):
        gender = 'Male' if self.radio_male.isChecked() else 'Female'
        name = self.text_name.text()
        print(f"Name: {name}\nGender: {gender}")


if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = MainWindow()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3259: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### Removed Button of "Submit Image" and gave a default Address

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QRadioButton, QLineEdit, QPushButton, QVBoxLayout, QHBoxLayout, QFileDialog
from PyQt5.QtGui import QPixmap
from PyQt5.QtCore import Qt


class MainWindow(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    def initUI(self):
        # Create radio buttons
        self.radio_male = QRadioButton('Male')
        self.radio_female = QRadioButton('Female')
        self.radio_male.setChecked(True)  # Set default as Male

        # Create name text box
        self.text_name = QLineEdit()

        # Create image box
        self.image_label = QLabel()
        self.image_label.setFixedSize(200, 200)

        # Create video text box
        self.video_label = QLabel()
        self.video_label.setFixedSize(200, 200)
        self.btn_upload_video = QPushButton('Upload Video')
        self.btn_upload_video.clicked.connect(self.openVideo)

        # Create buttons
        self.btn_submit_video = QPushButton('Submit Video')
        self.btn_submit_name_gender = QPushButton('Save Name and Gender')
        self.btn_submit_name_gender.clicked.connect(self.saveNameGender)

        # Create layouts
        layout_gender = QHBoxLayout()
        layout_gender.addWidget(self.radio_male)
        layout_gender.addWidget(self.radio_female)

        layout_name = QHBoxLayout()
        layout_name.addWidget(QLabel('Name: '))
        layout_name.addWidget(self.text_name)

        layout_image = QVBoxLayout()
        layout_image.addWidget(QLabel('Image:'))
        layout_image.addWidget(self.image_label)

        layout_video = QVBoxLayout()
        layout_video.addWidget(QLabel('Video:'))
        layout_video.addWidget(self.video_label)
        layout_video.addWidget(self.btn_upload_video)

        layout_buttons = QHBoxLayout()
        layout_buttons.addWidget(self.btn_submit_video)
        layout_buttons.addWidget(self.btn_submit_name_gender)

        layout_main = QVBoxLayout()
        layout_main.addLayout(layout_gender)
        layout_main.addLayout(layout_name)
        layout_main.addLayout(layout_image)
        layout_main.addLayout(layout_video)
        layout_main.addLayout(layout_buttons)

        self.setLayout(layout_main)
        self.setWindowTitle('My Application')
        self.show()

    def openImage(self):
        filename, _ = QFileDialog.getOpenFileName(self, "Select Image", "", "Image Files (*.png *.jpg *jpeg *.bmp)")
        if filename:
            pixmap = QPixmap(filename)
            pixmap = pixmap.scaled(200, 200, Qt.KeepAspectRatio)
            self.image_label.setPixmap(pixmap)

    def openVideo(self):
        filename, _ = QFileDialog.getOpenFileName(self, "Select Video", "", "Video Files (*.mp4)")
        if filename:
            self.video_label.setText(filename)

    def saveNameGender(self):
        gender = 'Male' if self.radio_male.isChecked() else 'Female'
        name = self.text_name.text()
        print(f"Name: {name}\nGender: {gender}")
        pixmap = QPixmap("/Users/phoenix/Desktop/Screenshot 2023-04-02 at 8.23.43 PM.png")
        pixmap = pixmap.scaled(200, 200, Qt.KeepAspectRatio)
        self.image_label.setPixmap(pixmap)


if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = MainWindow()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3259: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### Saving Video File

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QRadioButton, QLineEdit, QPushButton, QVBoxLayout, QHBoxLayout, QFileDialog
from PyQt5.QtGui import QPixmap
from PyQt5.QtCore import Qt


class MainWindow(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    def initUI(self):
        # Create radio buttons
        self.radio_male = QRadioButton('Male')
        self.radio_female = QRadioButton('Female')
        self.radio_male.setChecked(True)  # Set default as Male

        # Create name text box
        self.text_name = QLineEdit()

        # Create image box
        self.image_label = QLabel()
        self.image_label.setFixedSize(200, 200)

        # Create video box
        self.video_label = QLabel()
        self.video_label.setFixedSize(200, 200)

        # Create buttons
        self.btn_upload_video = QPushButton('Upload Video')
        self.btn_upload_video.clicked.connect(self.openVideo)
        self.btn_submit_video = QPushButton('Submit Video')
        self.btn_submit_video.clicked.connect(self.submitVideo)
        self.btn_submit_name_gender = QPushButton('Save Name and Gender')
        self.btn_submit_name_gender.clicked.connect(self.saveNameGender)

        # Create layouts
        layout_gender = QHBoxLayout()
        layout_gender.addWidget(self.radio_male)
        layout_gender.addWidget(self.radio_female)

        layout_name = QHBoxLayout()
        layout_name.addWidget(QLabel('Name: '))
        layout_name.addWidget(self.text_name)

        layout_image = QVBoxLayout()
        layout_image.addWidget(QLabel('Image:'))
        layout_image.addWidget(self.image_label)

        layout_video = QVBoxLayout()
        layout_video.addWidget(QLabel('Video:'))
        layout_video.addWidget(self.video_label)
        layout_video.addWidget(self.btn_upload_video)

        layout_buttons = QHBoxLayout()
        layout_buttons.addWidget(self.btn_submit_video)
        layout_buttons.addWidget(self.btn_submit_name_gender)

        layout_main = QVBoxLayout()
        layout_main.addLayout(layout_gender)
        layout_main.addLayout(layout_name)
        layout_main.addLayout(layout_image)
        layout_main.addLayout(layout_video)
        layout_main.addLayout(layout_buttons)

        self.setLayout(layout_main)
        self.setWindowTitle('My Application')
        self.show()

        self.video_path = ""


    def openVideo(self):
        filename, _ = QFileDialog.getOpenFileName(self, "Select Video", "", "Video Files (*.mp4)")
        if filename:
            self.video_label.setText(filename)
            self.video_path = filename

    def submitVideo(self):
        if self.video_path:
            print(f"Video Path: {self.video_path}")
        else:
            print("Please select a video file.")

    def saveNameGender(self):
        gender = 'Male' if self.radio_male.isChecked() else 'Female'
        name = self.text_name.text()
        print(f"Name: {name}\nGender: {gender}")


if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = MainWindow()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3259: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Layout 1

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QRadioButton, QLineEdit, QPushButton, QVBoxLayout, QHBoxLayout, QFileDialog
from PyQt5.QtGui import QPixmap
from PyQt5.QtCore import Qt


class MainWindow(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    def initUI(self):
        # Create name text box
        self.text_name = QLineEdit()

        # Create radio buttons
        self.radio_male = QRadioButton('Male')
        self.radio_female = QRadioButton('Female')
        self.radio_male.setChecked(True)  # Set default as Male

        # Create layouts for name and gender
        layout_name_gender = QHBoxLayout()
        layout_name_gender.addWidget(QLabel('Name: '))
        layout_name_gender.addWidget(self.text_name)
        layout_name_gender.addWidget(self.radio_male)
        layout_name_gender.addWidget(self.radio_female)

        # Create image box
        self.image_label = QLabel()
        self.image_label.setFixedSize(200, 200)

        # Create video box
        self.video_label = QLabel()
        self.video_label.setFixedSize(200, 200)

        # Create buttons
        self.btn_upload_video = QPushButton('Upload Video')
        self.btn_upload_video.clicked.connect(self.openVideo)
        self.btn_submit_video = QPushButton('Submit Video')
        self.btn_submit_video.clicked.connect(self.submitVideo)
        self.btn_submit_name_gender = QPushButton('Save Name and Gender')
        self.btn_submit_name_gender.clicked.connect(self.saveNameGender)

        # Create layouts for video and image
        layout_video_image = QHBoxLayout()
        layout_video_image.addWidget(self.video_label)
        layout_video_image.addWidget(self.image_label)

        # Create layout for buttons
        layout_buttons = QHBoxLayout()
        layout_buttons.addWidget(self.btn_upload_video)
        layout_buttons.addWidget(self.btn_submit_video)
        layout_buttons.addWidget(self.btn_submit_name_gender)

        # Create main layout
        layout_main = QVBoxLayout()
        layout_main.addLayout(layout_name_gender)
        layout_main.addLayout(layout_video_image)
        layout_main.addLayout(layout_buttons)

        self.setLayout(layout_main)
        self.setWindowTitle('My Application')
        self.show()

        self.video_path = ""

    def openVideo(self):
        filename, _ = QFileDialog.getOpenFileName(self, "Select Video", "", "Video Files (*.mp4)")
        if filename:
            self.video_label.setText(filename)
            self.video_path = filename

    def submitVideo(self):
        if self.video_path:
            print(f"Video Path: {self.video_path}")
        else:
            print("Please select a video file.")

    def saveNameGender(self):
        gender = 'Male' if self.radio_male.isChecked() else 'Female'
        name = self.text_name.text()
        print(f"Name: {name}\nGender: {gender}")
        pixmap = QPixmap("/Users/phoenix/Desktop/Screenshot 2023-04-02 at 8.23.43 PM.png")
        pixmap = pixmap.scaled(200, 200, Qt.KeepAspectRatio)
        self.image_label.setPixmap(pixmap)



if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = MainWindow()
    sys.exit(app.exec_())
# Out:
# Please select a video file.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3259: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Final Layout

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QRadioButton, QLineEdit, QPushButton, QVBoxLayout, QHBoxLayout, QFileDialog
from PyQt5.QtGui import QPixmap
from PyQt5.QtCore import Qt


class MainWindow(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    def initUI(self):
        # Create name text box
        self.text_name = QLineEdit()

        # Create radio buttons
        self.radio_male = QRadioButton('Male')
        self.radio_female = QRadioButton('Female')
        self.radio_male.setChecked(True)  # Set default as Male

        # Create layouts for name and gender
        layout_name_gender = QHBoxLayout()
        layout_name_gender.addWidget(QLabel('Name: '))
        layout_name_gender.addWidget(self.text_name)
        layout_name_gender.addWidget(QLabel('Gender: '))
        layout_name_gender.addWidget(self.radio_male)
        layout_name_gender.addWidget(self.radio_female)

        # Create image box
        self.image_label = QLabel()
        self.image_label.setFixedSize(200, 200)

        # Create video box
        self.video_label = QLabel()
        self.video_label.setFixedSize(200, 200)

        # Create buttons
        self.btn_upload_video = QPushButton('Upload Video')
        self.btn_upload_video.clicked.connect(self.openVideo)
        self.btn_generate_report = QPushButton('Generate Report')
        self.btn_generate_report.clicked.connect(self.generateReport)

        # Create layouts for video and image
        layout_video_image = QHBoxLayout()
        layout_video_image.addWidget(self.video_label)
        layout_video_image.addWidget(self.image_label)

        # Create layout for buttons
        layout_buttons = QHBoxLayout()
        layout_buttons.addWidget(self.btn_upload_video)
        layout_buttons.addWidget(self.btn_generate_report)

        # Create main layout
        layout_main = QVBoxLayout()
        layout_main.addLayout(layout_name_gender)
        layout_main.addLayout(layout_video_image)
        layout_main.addLayout(layout_buttons)

        self.setLayout(layout_main)
        self.setWindowTitle('My Application')
        self.show()

        self.video_path = ""

    def openVideo(self):
        filename, _ = QFileDialog.getOpenFileName(self, "Select Video", "", "Video Files (*.mp4)")
        if filename:
            self.video_label.setText(filename)
            self.video_path = filename

    def generateReport(self):
        gender = 'Male' if self.radio_male.isChecked() else 'Female'
        name = self.text_name.text()
        if self.video_path:
            print(f"Name: {name}\nGender: {gender}\nVideo Path: {self.video_path}")
            pixmap = QPixmap("/Users/phoenix/Desktop/Screenshot 2023-04-02 at 8.23.43 PM.png")
            pixmap = pixmap.scaled(200, 200, Qt.KeepAspectRatio)
            self.image_label.setPixmap(pixmap)
        else:
            print("Please select a video file.")

if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = MainWindow()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\Admin\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3259: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Code to convert the Video into a CSV File

# %%
# import cv2
# import numpy as np
# from os import listdir
# from os.path import isfile, join

# path = filename
# dataStoredAt = path[:-4]+'.csv'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Admin\Downloads\PyQt5 Application.ipynb Cell 14 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/PyQt5%20Application.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> from os import listdir
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/PyQt5%20Application.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> from os.path import isfile, join
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/PyQt5%20Application.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> path = filename
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/PyQt5%20Application.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> dataStoredAt = path[:-4]+'.csv'
#
# NameError: name 'filename' is not defined
